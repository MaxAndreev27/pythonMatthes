# %% [markdown]
# # Chapter 13 - Data Science
# ## Data Preparation

# %% [markdown]
# ## 0 - Setting up the notebook

# %%
import json
import random
from datetime import date, timedelta

import faker

# %% [markdown]
# ## 1 - Preparing the Data

# %%
# create the faker to populate the data
fake = faker.Faker()

# %%
# generate user profiles
# simulate user data coming from an API. It is a list
# of JSON strings (users).
def get_users(no_of_users):
    usernames = (
        fake.unique.user_name() for i in range(no_of_users)
    )
    genders = random.choices(
        ["M", "F", "O"], weights=[0.43, 0.47, 0.1], k=no_of_users
    )
    for username, gender in zip(usernames, genders):
        user = {
            "username": username,
            "name": get_random_name(gender),
            "gender": gender,
            "email": fake.email(),
            "age": fake.random_int(min=18, max=90),
            "address": fake.address(),
        }
        yield json.dumps(user)


def get_random_name(gender):
    match gender:
        case "F":
            name = fake.name_female()
        case "M":
            name = fake.name_male()
        case _:
            name = fake.name_nonbinary()
    return name


users = list(get_users(1000))
users[:3]
# Out:
# ['{"username": "terrijoseph", "name": "Tanya Wong", "gender": "F", "email": "keithnguyen@example.net", "age": 51, "address": "195 Sarah Trail Apt. 397\\nLake Marcusfort, AR 79955"}',
#  '{"username": "curtishall", "name": "Kevin Hoffman", "gender": "M", "email": "robertabrown@example.com", "age": 26, "address": "4177 John Cliff\\nPatelmouth, GA 24762"}',
#  '{"username": "thomaszuniga", "name": "Christopher Perez", "gender": "M", "email": "brian06@example.net", "age": 57, "address": "084 Thomas Corner Suite 421\\nNew Emilyfurt, TX 45072"}']

# %%
# campaign name format:
# InternalType_StartDate_EndDate_TargetAge_TargetGender_Currency
def get_type():
    # just some meaningless example codes
    types = ["AKX", "BYU", "GRZ", "KTR"]
    return random.choice(types)


def get_start_end_dates():
    duration = random.randint(1, 2 * 365)
    offset = random.randint(-365, 365)
    start = date.today() - timedelta(days=offset)
    end = start + timedelta(days=duration)

    def _format_date(date_):
        return date_.strftime("%Y%m%d")

    return _format_date(start), _format_date(end)


def get_age_range():
    age = random.randrange(20, 46, 5)
    diff = random.randrange(5, 26, 5)
    return "{}-{}".format(age, age + diff)


def get_gender():
    return random.choice(("M", "F", "A"))


def get_currency():
    return random.choice(("GBP", "EUR", "USD"))


def get_campaign_name():
    separator = "_"
    type_ = get_type()
    start, end = get_start_end_dates()
    age_range = get_age_range()
    gender = get_gender()
    currency = get_currency()
    return separator.join(
        (type_, start, end, age_range, gender, currency)
    )

# %%
# campaign data:
# name, budget, spent, clicks, impressions
def get_campaign_data():
    name = get_campaign_name()
    budget = random.randint(10**3, 10**6)
    spent = random.randint(10**2, budget)
    clicks = int(random.triangular(10**2, 10**5, 0.2 * 10**5))
    impressions = int(random.gauss(0.5 * 10**6, 2))
    return {
        "cmp_name": name,
        "cmp_bgt": budget,
        "cmp_spent": spent,
        "cmp_clicks": clicks,
        "cmp_impr": impressions,
    }

# %%
# assemble the logic to get the final version of the rough data
# data will be a list of dictionaries. Each dictionary will follow
# this structure:
# {'user': user_json, 'campaigns': [c1, c2, ...]}
# where user_json is the JSON string version of a user data dict
# and c1, c2, ... are campaign dicts as returned by
# get_campaign_data


def get_data(users):
    data = []
    for user in users:
        campaigns = [
            get_campaign_data()
            for _ in range(random.randint(2, 8))
        ]
        data.append({"user": user, "campaigns": campaigns})
    return data

# %% [markdown]
# ## 2 - Cleaning the data

# %%
# fetch simulated rough data
rough_data = get_data(users)

rough_data[:2]  # let us take a peek
# Out:
# [{'user': '{"username": "terrijoseph", "name": "Tanya Wong", "gender": "F", "email": "keithnguyen@example.net", "age": 51, "address": "195 Sarah Trail Apt. 397\\nLake Marcusfort, AR 79955"}',
#   'campaigns': [{'cmp_name': 'AKX_20261006_20280414_20-35_A_USD',
#     'cmp_bgt': 241528,
#     'cmp_spent': 7991,
#     'cmp_clicks': 59941,
#     'cmp_impr': 500000},
#    {'cmp_name': 'KTR_20260825_20261103_40-45_A_USD',
#     'cmp_bgt': 395185,
#     'cmp_spent': 128004,
#     'cmp_clicks': 25319,
#     'cmp_impr': 500000},
#    {'cmp_name': 'KTR_20260726_20270411_25-45_M_EUR',
#     'cmp_bgt': 525716,
#     'cmp_spent': 53273,
#     'cmp_clicks': 34660,
#     'cmp_impr': 500001},
#    {'cmp_name': 'AKX_20270323_20270729_40-55_F_EUR',
#     'cmp_bgt': 995076,
#     'cmp_spent': 855387,
#     'cmp_clicks': 58794,
#     'cmp_impr': 500000},
#    {'cmp_name': 'KTR_20260304_20270212_20-45_A_GBP',
#     'cmp_bgt': 132863,
#     'cmp_spent': 119430,
#     'cmp_clicks': 57185,
#     'cmp_impr': 499999},
#    {'cmp_name': 'KTR_20270205_20281214_30-35_A_GBP',
#     'cmp_bgt': 937882,
#     'cmp_spent': 12589,
#     'cmp_clicks': 79080,
#     'cmp_impr': 499998},
#    {'cmp_name': 'BYU_20261212_20270718_20-35_A_EUR',
#     'cmp_bgt': 518365,
#     'cmp_spent': 344688,
#     'cmp_clicks': 9937,
#     'cmp_impr': 500002}]},
#  {'user': '{"username": "curtishall", "name": "Kevin Hoffman", "gender": "M", "email": "robertabrown@example.com", "age": 26, "address": "4177 John Cliff\\nPatelmouth, GA 24762"}',
#   'campaigns': [{'cmp_name': 'AKX_20260730_20270706_45-65_F_EUR',
#     'cmp_bgt': 110218,
#     'cmp_spent': 39161,
#     'cmp_clicks': 51612,
#     'cmp_impr': 499996},
#    {'cmp_name': 'AKX_20260516_20280304_20-25_A_EUR',
#     'cmp_bgt': 593317,
#     'cmp_spent': 62568,
#     'cmp_clicks': 37398,
#     'cmp_impr': 500000},
#    {'cmp_name': 'AKX_20260829_20271024_30-35_M_GBP',
#     'cmp_bgt': 208133,
#     'cmp_spent': 38612,
#     'cmp_clicks': 20765,
#     'cmp_impr': 499997},
#    {'cmp_name': 'BYU_20250910_20260719_45-70_A_USD',
#     'cmp_bgt': 581840,
#     'cmp_spent': 397979,
#     'cmp_clicks': 31962,
#     'cmp_impr': 499996},
#    {'cmp_name': 'GRZ_20261120_20261127_25-50_A_GBP',
#     'cmp_bgt': 479206,
#     'cmp_spent': 329553,
#     'cmp_clicks': 32246,
#     'cmp_impr': 499999},
#    {'cmp_name': 'BYU_20250601_20270330_25-35_M_GBP',
#     'cmp_bgt': 160857,
#     'cmp_spent': 87376,
#     'cmp_clicks': 12526,
#     'cmp_impr': 499999},
#    {'cmp_name': 'KTR_20251029_20271006_45-65_M_EUR',
#     'cmp_bgt': 980139,
#     'cmp_spent': 822720,
#     'cmp_clicks': 5553,
#     'cmp_impr': 500000},
#    {'cmp_name': 'GRZ_20250921_20260219_45-70_M_USD',
#     'cmp_bgt': 949638,
#     'cmp_spent': 918339,
#     'cmp_clicks': 61779,
#     'cmp_impr': 499997}]}]

# %%
# Let's start from having a different version of the data
# We want a list whose items will be dicts. Each dict is
# the original campaign dict plus the user JSON

data = []
for datum in rough_data:
    for campaign in datum["campaigns"]:
        campaign.update({"user": datum["user"]})
        data.append(campaign)
data[:2]  # let us take another peek
# Out:
# [{'cmp_name': 'AKX_20261006_20280414_20-35_A_USD',
#   'cmp_bgt': 241528,
#   'cmp_spent': 7991,
#   'cmp_clicks': 59941,
#   'cmp_impr': 500000,
#   'user': '{"username": "terrijoseph", "name": "Tanya Wong", "gender": "F", "email": "keithnguyen@example.net", "age": 51, "address": "195 Sarah Trail Apt. 397\\nLake Marcusfort, AR 79955"}'},
#  {'cmp_name': 'KTR_20260825_20261103_40-45_A_USD',
#   'cmp_bgt': 395185,
#   'cmp_spent': 128004,
#   'cmp_clicks': 25319,
#   'cmp_impr': 500000,
#   'user': '{"username": "terrijoseph", "name": "Tanya Wong", "gender": "F", "email": "keithnguyen@example.net", "age": 51, "address": "195 Sarah Trail Apt. 397\\nLake Marcusfort, AR 79955"}'}]

# %%
# Warning: Uncommenting and executing this cell will overwrite data.json
# with open("data.json", "w") as stream:
#     stream.write(json.dumps(data))
