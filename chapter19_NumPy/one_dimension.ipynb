# %%
import numpy as np
nums_array = np.array([1,2,3,4,5])
nums_array
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(nums_array)
# Out:
# numpy.ndarray

# %%
nums_array[0]
nums_array[-1]
# Out:
# np.int64(5)

# %%
# Форма массива та кількість елементів
nums_array.shape
# Out:
# (5,)

# %%
# Розмірність (одномірний)
nums_array.ndim
# Out:
# 1

# %%
# Розмір масива
nums_array.size
# Out:
# 5

# %%
# Тип елементів
nums_array.dtype
# Out:
# dtype('int64')

# %%
# Скільки один елемент займає пам'яті
nums_array.itemsize
# Out:
# 8
