# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('vehicles.csv')
df.head(8)
# Out:
#    Age  Gender  Income Favorite Transport
# 0    5  female     NaN            bicycle
# 1    8    male     NaN            scooter
# 2   10  female     NaN            bicycle
# 3   14    male     NaN              metro
# 4   16    male     NaN              metro
# 5   18  female     NaN              metro
# 6   20    male   200.0            scooter
# 7   22  female   500.0            scooter

# %%
df.dtypes
# Out:
# Age                     int64
# Gender                    str
# Income                float64
# Favorite Transport        str
# dtype: object

# %% [markdown]
# ## Cleaning

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Income                6
# Favorite Transport    0
# dtype: int64

# %%
df["Income"] = df["Income"].fillna(0.0)
df.head(8)
# Out:
#    Age  Gender  Income Favorite Transport
# 0    5  female     0.0            bicycle
# 1    8    male     0.0            scooter
# 2   10  female     0.0            bicycle
# 3   14    male     0.0              metro
# 4   16    male     0.0              metro
# 5   18  female     0.0              metro
# 6   20    male   200.0            scooter
# 7   22  female   500.0            scooter

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Income                0
# Favorite Transport    0
# dtype: int64

# %% [markdown]
# ## Encoding

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['female', 'male']
# Length: 2, dtype: str

# %%
# # OPTION 1
# df.replace({
#     'Gender': {
#         'male': 0,
#         'female': 1
#     }
# }, inplace=True)
# df.head()

# %%
# OPTION 2
label_encoder = LabelEncoder()
df["Gender"] = label_encoder.fit_transform(df["Gender"]).tolist()
df.head(8)
# Out:
#    Age  Gender  Income Favorite Transport
# 0    5       0     0.0            bicycle
# 1    8       1     0.0            scooter
# 2   10       0     0.0            bicycle
# 3   14       1     0.0              metro
# 4   16       1     0.0              metro
# 5   18       0     0.0              metro
# 6   20       1   200.0            scooter
# 7   22       0   500.0            scooter

# %%
df.dtypes
# Out:
# Age                     int64
# Gender                  int64
# Income                float64
# Favorite Transport        str
# dtype: object

# %% [markdown]
# ## Model

# %%
X = df.drop(columns='Favorite Transport')
X.head(3)
# Out:
#    Age  Gender  Income
# 0    5       0     0.0
# 1    8       1     0.0
# 2   10       0     0.0

# %%
y = df['Favorite Transport']
y.head(3)
# Out:
# 0    bicycle
# 1    scooter
# 2    bicycle
# Name: Favorite Transport, dtype: str

# %%
model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Prediction

# %%
test_df = pd.DataFrame({
    'Age': [12, 30, 75],
    'Gender': [0, 0, 1],
    'Income': [0.0, 4000, 50000]
})
test_df
# Out:
#    Age  Gender   Income
# 0   12       0      0.0
# 1   30       0   4000.0
# 2   75       1  50000.0

# %%
model.predict(test_df)
# Out:
# array(['bicycle', 'car', 'helicopter'], dtype=object)

# %% [markdown]
# ## Exporting to the DOT file

# %%
tree.export_graphviz(model, out_file='decision_tree_model.dot', feature_names=['Age', 'Gender', 'Income'], filled=True, class_names=sorted(y.unique()))

# %% [markdown]
# ## Evaluation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X.shape
# Out:
# (26, 3)

# %%
X_train.shape
# Out:
# (20, 3)

# %%
X_test.shape
# Out:
# (6, 3)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_test
# Out:
#     Age  Gender   Income
# 3    14       1      0.0
# 18   56       0   1400.0
# 14   45       1   3000.0
# 22   68       1  20000.0
# 25   75       1  30000.0
# 15   47       0   6000.0

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array(['metro', 'taxi', 'car', 'helicopter', 'helicopter', 'car'],
#       dtype=object)

# %%
model_accuracy_score = accuracy_score(y_test, predictions)
model_accuracy_score
# Out:
# 0.8333333333333334

# %% [markdown]
# ## Charts

# %%
sns.countplot(x=df['Gender'], hue=df['Favorite Transport'])
plt.show()

# %%
sns.histplot(x=df['Income'], hue=df['Favorite Transport'])
plt.show()
